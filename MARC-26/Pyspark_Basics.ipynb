# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.2)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Pyspark Basics").getOrCreate()
print("Spark Session Created")
# Out:
# Spark Session Created

# %%
print(spark.version)
# Out:
# 4.0.2

# %%
data=[("Rahul",25,"Hyderabad"),("Sneha",28,"Bangalore"),("Arjun",24,"Chennai"),("Priya",27,"Hyderabad")]
columns=["Name","Age","City"]
df=spark.createDataFrame(data,columns)
df.show()
# Out:
# +-----+---+---------+
# | Name|Age|     City|
# +-----+---+---------+
# |Rahul| 25|Hyderabad|
# |Sneha| 28|Bangalore|
# |Arjun| 24|  Chennai|
# |Priya| 27|Hyderabad|
# +-----+---+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: long (nullable = true)
#  |-- City: string (nullable = true)

# %%
df.select("Name").show()
# Out:
# +-----+
# | Name|
# +-----+
# |Rahul|
# |Sneha|
# |Arjun|
# |Priya|
# +-----+

# %%
df.select("Name","City").show()
# Out:
# +-----+---------+
# | Name|     City|
# +-----+---------+
# |Rahul|Hyderabad|
# |Sneha|Bangalore|
# |Arjun|  Chennai|
# |Priya|Hyderabad|
# +-----+---------+

# %%
df.filter(df.Age>25).show()
# Out:
# +-----+---+---------+
# | Name|Age|     City|
# +-----+---+---------+
# |Sneha| 28|Bangalore|
# |Priya| 27|Hyderabad|
# +-----+---+---------+

# %%
df.groupBy("City").count().show()
# Out:
# +---------+-----+
# |     City|count|
# +---------+-----+
# |Bangalore|    1|
# |Hyderabad|    2|
# |  Chennai|    1|
# +---------+-----+

# %%
df.orderBy("Age").show()
# Out:
# +-----+---+---------+
# | Name|Age|     City|
# +-----+---+---------+
# |Arjun| 24|  Chennai|
# |Rahul| 25|Hyderabad|
# |Priya| 27|Hyderabad|
# |Sneha| 28|Bangalore|
# +-----+---+---------+

# %%
df.orderBy(df.Age.desc()).show()
# Out:
# +-----+---+---------+
# | Name|Age|     City|
# +-----+---+---------+
# |Sneha| 28|Bangalore|
# |Priya| 27|Hyderabad|
# |Rahul| 25|Hyderabad|
# |Arjun| 24|  Chennai|
# +-----+---+---------+
