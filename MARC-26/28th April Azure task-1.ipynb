# %%
from pyspark.sql.functions import *

# %%
data = [
(101,"Olivia Bennett","London","Engineering",92000,5),
(102,"Ethan Walker","New York","Marketing",75000,4),
(103,"Sophia Turner","Toronto","Finance",88000,6),
(104,"Liam Carter","Sydney","Engineering",97000,7),
(105,"Mia Collins","Berlin","HR",69000,3),
(106,"Noah Parker","Paris","Marketing",72000,4),
(107,"Ava Reed","Tokyo","Finance",91000,6),
(108,"Lucas Hayes","Madrid","Engineering",85000,5),
(109,"Isabella Cruz","Rome","Finance",93000,8),
(110,"Mason Gray","Chicago","Engineering",89000,6),
(111,"Charlotte Fox","Dublin","HR",67000,3),
(112,"Benjamin Stone","Boston","Marketing",76000,4),
(113,"Amelia Knight","Amsterdam","Engineering",94000,7),
(114,"James Holt","San Francisco","Finance",99000,9),
(115,"Harper Lane","Melbourne","HR",64000,2),
(116,"Alexander West","Seattle","Engineering",96000,7),
(117,"Evelyn Scott","Vancouver","Marketing",74000,4),
(118,"Henry Brooks","Zurich","Finance",97000,8),
(119,"Ella Simmons","Stockholm","Engineering",88000,6),
(120,"Daniel Ward","Singapore","Marketing",77000,5)
]
columns = ["emp_id","name","city","department","salary","experience"]
df = spark.createDataFrame(data,columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#1
display(df)
#2
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#3
df.count()
# Out:
# 20

# %%
#4
df.show(5)
# Out:
# +------+--------------+--------+-----------+------+----------+
# |emp_id|          name|    city| department|salary|experience|
# +------+--------------+--------+-----------+------+----------+
# |   101|Olivia Bennett|  London|Engineering| 92000|         5|
# |   102|  Ethan Walker|New York|  Marketing| 75000|         4|
# |   103| Sophia Turner| Toronto|    Finance| 88000|         6|
# |   104|   Liam Carter|  Sydney|Engineering| 97000|         7|
# |   105|   Mia Collins|  Berlin|         HR| 69000|         3|
# +------+--------------+--------+-----------+------+----------+
# only showing top 5 rows

# %%
#5
display(df.tail(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#6
df.columns
# Out:
# ['emp_id', 'name', 'city', 'department', 'salary', 'experience']

# %%
#7
df.select("name","salary").show()
#8
df.select("name","department","experience").show()
#9
df.select("department").distinct().show()
#10
df.select("city").distinct().show()
# Out:
# +--------------+------+
# |          name|salary|
# +--------------+------+
# |Olivia Bennett| 92000|
# |  Ethan Walker| 75000|
# | Sophia Turner| 88000|
# |   Liam Carter| 97000|
# |   Mia Collins| 69000|
# |   Noah Parker| 72000|
# |      Ava Reed| 91000|
# |   Lucas Hayes| 85000|
# | Isabella Cruz| 93000|
# |    Mason Gray| 89000|
# | Charlotte Fox| 67000|
# |Benjamin Stone| 76000|
# | Amelia Knight| 94000|
# |    James Holt| 99000|
# |   Harper Lane| 64000|
# |Alexander West| 96000|
# |  Evelyn Scott| 74000|
# |  Henry Brooks| 97000|
# |  Ella Simmons| 88000|
# |   Daniel Ward| 77000|
# +--------------+------+
#
# +--------------+-----------+----------+
# |          name| department|experience|
# +--------------+-----------+----------+
# |Olivia Bennett|Engineering|         5|
# |  Ethan Walker|  Marketing|         4|
# | Sophia Turner|    Finance|         6|
# |   Liam Carter|Engineering|         7|
# |   Mia Collins|         HR|         3|
# ...

# %%
#11
df.filter(col("salary") > 90000).show()
#12
df.filter(col("department") == "Engineering").show()
#13
df.filter(col("department") == "Marketing").show()
#14
df.filter(col("experience") > 6).show()
#15
df.filter(col("salary") < 70000).show()
#16
df.filter(col("city") == "London").show()
#17
df.filter((col("department")=="Finance") & (col("salary")>90000)).show()
#18
df.filter((col("department")=="Engineering") & (col("experience")>5)).show()
#19
df.filter(col("salary").between(85000,95000)).show()
#20
df.filter(col("experience") < 4).show()
# Out:
# +------+--------------+-------------+-----------+------+----------+
# |emp_id|          name|         city| department|salary|experience|
# +------+--------------+-------------+-----------+------+----------+
# |   101|Olivia Bennett|       London|Engineering| 92000|         5|
# |   104|   Liam Carter|       Sydney|Engineering| 97000|         7|
# |   107|      Ava Reed|        Tokyo|    Finance| 91000|         6|
# |   109| Isabella Cruz|         Rome|    Finance| 93000|         8|
# |   113| Amelia Knight|    Amsterdam|Engineering| 94000|         7|
# |   114|    James Holt|San Francisco|    Finance| 99000|         9|
# |   116|Alexander West|      Seattle|Engineering| 96000|         7|
# |   118|  Henry Brooks|       Zurich|    Finance| 97000|         8|
# +------+--------------+-------------+-----------+------+----------+
#
# +------+--------------+---------+-----------+------+----------+
# |emp_id|          name|     city| department|salary|experience|
# ...

# %%
#21
df.orderBy("salary").show()
#22
df.orderBy(col("salary").desc()).show()
#23
df.orderBy("experience").show()
#24
df.orderBy(col("experience").desc()).show()
#25
df.orderBy("department").show()
#26
df.orderBy("city").show()
#27
df.orderBy("department","salary").show()
#28
df.orderBy(col("salary").desc()).show(5)
#29
df.orderBy("salary").show(5)
#30
df.orderBy(col("experience").desc()).show(3)
# Out:
# +------+--------------+-------------+-----------+------+----------+
# |emp_id|          name|         city| department|salary|experience|
# +------+--------------+-------------+-----------+------+----------+
# |   115|   Harper Lane|    Melbourne|         HR| 64000|         2|
# |   111| Charlotte Fox|       Dublin|         HR| 67000|         3|
# |   105|   Mia Collins|       Berlin|         HR| 69000|         3|
# |   106|   Noah Parker|        Paris|  Marketing| 72000|         4|
# |   117|  Evelyn Scott|    Vancouver|  Marketing| 74000|         4|
# |   102|  Ethan Walker|     New York|  Marketing| 75000|         4|
# |   112|Benjamin Stone|       Boston|  Marketing| 76000|         4|
# |   120|   Daniel Ward|    Singapore|  Marketing| 77000|         5|
# |   108|   Lucas Hayes|       Madrid|Engineering| 85000|         5|
# |   103| Sophia Turner|      Toronto|    Finance| 88000|         6|
# |   119|  Ella Simmons|    Stockholm|Engineering| 88000|         6|
# ...

# %%
#31
df1 = df.withColumn("annual_salary", col("salary")*12)
df1.show()
#32
df2 = df.withColumn("salary_in_thousands", col("salary")/1000)
df2.show()
#33
df3 = df.withColumn("experience_double", col("experience")*2)
df3.show()
#34
df4 = df.withColumn("company", lit("GlobalTech"))
df4.show()
#35
df5 = df.withColumn("salary_after_bonus", col("salary")+5000)
df5.show()
#36
df6 = df.withColumn("salary_after_tax", col("salary")*0.9)
df6.show()
#37
df7 = df.withColumn("experience_next_year", col("experience")+1)
df7.show()
#38
df8 = df.withColumn("salary_per_year_of_experience", col("salary")/col("experience"))
df8.show()
#39
df9 = df.withColumnRenamed("salary","monthly_salary")
df9.show()
#40
df10 = df3.drop("experience_double")
df10.show()
# Out:
# +------+--------------+-------------+-----------+------+----------+-------------+
# |emp_id|          name|         city| department|salary|experience|annual_salary|
# +------+--------------+-------------+-----------+------+----------+-------------+
# |   101|Olivia Bennett|       London|Engineering| 92000|         5|      1104000|
# |   102|  Ethan Walker|     New York|  Marketing| 75000|         4|       900000|
# |   103| Sophia Turner|      Toronto|    Finance| 88000|         6|      1056000|
# |   104|   Liam Carter|       Sydney|Engineering| 97000|         7|      1164000|
# |   105|   Mia Collins|       Berlin|         HR| 69000|         3|       828000|
# |   106|   Noah Parker|        Paris|  Marketing| 72000|         4|       864000|
# |   107|      Ava Reed|        Tokyo|    Finance| 91000|         6|      1092000|
# |   108|   Lucas Hayes|       Madrid|Engineering| 85000|         5|      1020000|
# ...

# %%
#41
df.select(sum("salary")).show()
#42
df.select(avg("salary")).show()
#43
df.select(max("salary")).show()
#44
df.select(min("salary")).show()
# Out:
# +-----------+
# |sum(salary)|
# +-----------+
# |    1683000|
# +-----------+
#
# +-----------+
# |avg(salary)|
# +-----------+
# |    84150.0|
# +-----------+
#
# +-----------+
# |max(salary)|
# +-----------+
# |      99000|
# +-----------+
#
# +-----------+
# |min(salary)|
# +-----------+
# |      64000|
# +-----------+

# %%
#45
df.count()
# Out:
# 20

# %%
#46
df.groupBy("department").count().show()
#47
df.groupBy("department").avg("salary").show()
#48
df.groupBy("department").max("salary").show()
#49
df.groupBy("department").min("salary").show()
#50
df.groupBy("department").sum("salary").show()
# Out:
# +-----------+-----+
# | department|count|
# +-----------+-----+
# |Engineering|    7|
# |  Marketing|    5|
# |    Finance|    5|
# |         HR|    3|
# +-----------+-----+
#
# +-----------+-----------------+
# | department|      avg(salary)|
# +-----------+-----------------+
# |Engineering|91571.42857142857|
# |  Marketing|          74800.0|
# |    Finance|          93600.0|
# |         HR|66666.66666666667|
# +-----------+-----------------+
#
# +-----------+-----------+
# | department|max(salary)|
# +-----------+-----------+
# |Engineering|      97000|
# |  Marketing|      77000|
# |    Finance|      99000|
# |         HR|      69000|
# +-----------+-----------+
#
# +-----------+-----------+
# | department|min(salary)|
# +-----------+-----------+
# |Engineering|      85000|
# |  Marketing|      72000|
# |    Finance|      88000|
# |         HR|      64000|
# +-----------+-----------+
#
# +-----------+-----------+
# | department|sum(salary)|
# +-----------+-----------+
# ...

# %%
#51
df.groupBy("city").count().show()
#52
df.groupBy("department").avg("experience").show()
#53
df.groupBy("department").max("experience").show()
#54
df.groupBy("city").sum("salary").show()
#55
df.groupBy("city").avg("salary").show()
#56
df.groupBy("city").max("salary").show()
#57
df.groupBy("city").min("salary").show()
#58
df.groupBy("city").avg("experience").show()
#59
df.groupBy("department","city").count().show()
#60
df.groupBy("department","city").sum("salary").show()
# Out:
# +-------------+-----+
# |         city|count|
# +-------------+-----+
# |       London|    1|
# |     New York|    1|
# |      Toronto|    1|
# |       Sydney|    1|
# |       Berlin|    1|
# |        Paris|    1|
# |        Tokyo|    1|
# |       Madrid|    1|
# |         Rome|    1|
# |      Chicago|    1|
# |       Dublin|    1|
# |       Boston|    1|
# |    Amsterdam|    1|
# |San Francisco|    1|
# |    Melbourne|    1|
# |      Seattle|    1|
# |    Vancouver|    1|
# |       Zurich|    1|
# |    Stockholm|    1|
# |    Singapore|    1|
# +-------------+-----+
#
# +-----------+------------------+
# | department|   avg(experience)|
# +-----------+------------------+
# |Engineering| 6.142857142857143|
# |  Marketing|               4.2|
# |    Finance|               7.4|
# |         HR|2.6666666666666665|
# +-----------+------------------+
#
# +-----------+---------------+
# | department|max(experience)|
# +-----------+---------------+
# |Engineering|              7|
# ...

# %%
#61
df_clean = df.dropDuplicates()
df_clean.show()
#62
df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns]).show()
#63
df.na.fill({"salary":0}).show()
#64
df.na.drop(subset=["department"]).show()
#65
avg_exp = df.select(avg("experience")).collect()[0][0]
df.na.fill({"experience":avg_exp}).show()
# Out:
# +------+--------------+-------------+-----------+------+----------+
# |emp_id|          name|         city| department|salary|experience|
# +------+--------------+-------------+-----------+------+----------+
# |   101|Olivia Bennett|       London|Engineering| 92000|         5|
# |   102|  Ethan Walker|     New York|  Marketing| 75000|         4|
# |   103| Sophia Turner|      Toronto|    Finance| 88000|         6|
# |   104|   Liam Carter|       Sydney|Engineering| 97000|         7|
# |   105|   Mia Collins|       Berlin|         HR| 69000|         3|
# |   106|   Noah Parker|        Paris|  Marketing| 72000|         4|
# |   107|      Ava Reed|        Tokyo|    Finance| 91000|         6|
# |   108|   Lucas Hayes|       Madrid|Engineering| 85000|         5|
# |   109| Isabella Cruz|         Rome|    Finance| 93000|         8|
# |   110|    Mason Gray|      Chicago|Engineering| 89000|         6|
# |   111| Charlotte Fox|       Dublin|         HR| 67000|         3|
# ...

# %%
#66
df_clean.count()
# Out:
# 20

# %%
#67
df.na.fill({"department":"Unknown"}).show()
#68
df.filter(col("salary") >= 60000).show()
#69
df.filter(col("experience") >= 2).show()
#70
cleaned_df = df.filter((col("salary") >= 60000) & (col("experience") >= 2))
display(cleaned_df)
# Out:
# +------+--------------+-------------+-----------+------+----------+
# |emp_id|          name|         city| department|salary|experience|
# +------+--------------+-------------+-----------+------+----------+
# |   101|Olivia Bennett|       London|Engineering| 92000|         5|
# |   102|  Ethan Walker|     New York|  Marketing| 75000|         4|
# |   103| Sophia Turner|      Toronto|    Finance| 88000|         6|
# |   104|   Liam Carter|       Sydney|Engineering| 97000|         7|
# |   105|   Mia Collins|       Berlin|         HR| 69000|         3|
# |   106|   Noah Parker|        Paris|  Marketing| 72000|         4|
# |   107|      Ava Reed|        Tokyo|    Finance| 91000|         6|
# |   108|   Lucas Hayes|       Madrid|Engineering| 85000|         5|
# |   109| Isabella Cruz|         Rome|    Finance| 93000|         8|
# |   110|    Mason Gray|      Chicago|Engineering| 89000|         6|
# |   111| Charlotte Fox|       Dublin|         HR| 67000|         3|
# ...
