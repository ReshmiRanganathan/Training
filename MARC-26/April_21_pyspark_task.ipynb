# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("April_21 pyspark task").getOrCreate()
print("Spark Session Created")
# Out:
# Spark Session Created

# %%
data = [("Arun", 45000, "HR"),("Priya", 55000, "IT"),("Kiran", 60000, "Finance"),("Meena", 52000, "IT"),("Rahul", 48000, "HR")]
columns=["Name", "Salary", "Department"]
df=spark.createDataFrame(data,columns)
df.show()
# Out:
# +-----+------+----------+
# | Name|Salary|Department|
# +-----+------+----------+
# | Arun| 45000|        HR|
# |Priya| 55000|        IT|
# |Kiran| 60000|   Finance|
# |Meena| 52000|        IT|
# |Rahul| 48000|        HR|
# +-----+------+----------+

# %%
df.select("Name", "Salary").show()
# Out:
# +-----+------+
# | Name|Salary|
# +-----+------+
# | Arun| 45000|
# |Priya| 55000|
# |Kiran| 60000|
# |Meena| 52000|
# |Rahul| 48000|
# +-----+------+

# %%
df.filter(df.Salary>50000).show()
# Out:
# +-----+------+----------+
# | Name|Salary|Department|
# +-----+------+----------+
# |Priya| 55000|        IT|
# |Kiran| 60000|   Finance|
# |Meena| 52000|        IT|
# +-----+------+----------+

# %%
df.groupBy("Department").count().show()
# Out:
# +----------+-----+
# |Department|count|
# +----------+-----+
# |        HR|    2|
# |        IT|    2|
# |   Finance|    1|
# +----------+-----+

# %%
df.orderBy("Salary").show()
# Out:
# +-----+------+----------+
# | Name|Salary|Department|
# +-----+------+----------+
# | Arun| 45000|        HR|
# |Rahul| 48000|        HR|
# |Meena| 52000|        IT|
# |Priya| 55000|        IT|
# |Kiran| 60000|   Finance|
# +-----+------+----------+
